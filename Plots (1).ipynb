# %%
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

main_fig = plt.figure(figsize = (16, 10))



with cbook.get_sample_data('C:\\Users\\Olaga\\Desktop\\HSE education\\CG\\plots\\1.png') as image_file:
    image = plt.imread(image_file)
ax1 = main_fig.add_subplot(3,6,1)
ax1.set_title('original', fontsize = 20)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(image)


with cbook.get_sample_data('C:\\Users\\Olaga\\Desktop\\HSE education\\CG\\plots\\2.png') as image_file:
    image = plt.imread(image_file)
ax1 = main_fig.add_subplot(3,6,7)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(image)


with cbook.get_sample_data('C:\\Users\\Olaga\\Desktop\\HSE education\\CG\\plots\\3.png') as image_file:
    image = plt.imread(image_file)
ax1 = main_fig.add_subplot(3,6,2)
ax1.set_title('Otsu + CP', fontsize = 20)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(image)

with cbook.get_sample_data('C:\\Users\\Olaga\\Desktop\\HSE education\\CG\\plots\\4.png') as image_file:
    image = plt.imread(image_file)
ax1 = main_fig.add_subplot(3,6,8)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(image)


with cbook.get_sample_data('C:\\Users\\Olaga\\Desktop\\HSE education\\CG\\plots\\5.png') as image_file:
    image = plt.imread(image_file)
ax1 = main_fig.add_subplot(3,6,3)
ax1.set_title('unet4nuclei', fontsize = 20)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(image)


with cbook.get_sample_data('C:\\Users\\Olaga\\Desktop\\HSE education\\CG\\plots\\6.png') as image_file:
    image = plt.imread(image_file)
ax1 = main_fig.add_subplot(3,6,9)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(image)


with cbook.get_sample_data('C:\\Users\\Olaga\\Desktop\\HSE education\\CG\\plots\\7.png') as image_file:
    image = plt.imread(image_file)
ax1 = main_fig.add_subplot(3,6,4)
ax1.set_title('ilastik', fontsize = 20)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(image)


with cbook.get_sample_data('C:\\Users\\Olaga\\Desktop\\HSE education\\CG\\plots\\8.png') as image_file:
    image = plt.imread(image_file)
ax1 = main_fig.add_subplot(3,6,10)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(image)

with cbook.get_sample_data('C:\\Users\\Olaga\\Desktop\\HSE education\\CG\\plots\\9.png') as image_file:
    image = plt.imread(image_file)
ax1 = main_fig.add_subplot(3,6,5)
ax1.set_title('GVF', fontsize = 20)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(image)

with cbook.get_sample_data('C:\\Users\\Olaga\\Desktop\\HSE education\\CG\\plots\\10.png') as image_file:
    image = plt.imread(image_file)
ax1 = main_fig.add_subplot(3,6,11)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(image)

with cbook.get_sample_data('C:\\Users\\Olaga\\Desktop\\HSE education\\CG\\plots\\11.png') as image_file:
    image = plt.imread(image_file)
ax1 = main_fig.add_subplot(3,6,6)
ax1.set_title('proposed', fontsize = 20)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(image)

with cbook.get_sample_data('C:\\Users\\Olaga\\Desktop\\HSE education\\CG\\plots\\12.png') as image_file:
    image = plt.imread(image_file)
ax1 = main_fig.add_subplot(3,6,12)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(image)


ax1 = main_fig.add_subplot(3,2,5)

ax1.set_title("DSB scores")
ax1.set_ylabel('Histology')

ax1.bar(x = ['Otsu + CP','unet4nuclei', 'ilastik', 'GVF', 'proposed'], height = [0.301, 0.006, 0.319, 0.055, 0.499],
      yerr= [0.05, 0.005, 0.05, 0.01, 0.1], capsize = 4, color = 'grey')
# Out:
# <BarContainer object of 5 artists>
